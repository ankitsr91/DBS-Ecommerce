# %%
# %sql
-- create catalog 
CREATE CATALOG dev;
CREATE CATALOG test;
CREATE CATALOG prod;

# %%
# %sql
-- create schema for dev
CREATE SCHEMA dev.bronze;
CREATE SCHEMA dev.silver;
CREATE SCHEMA dev.gold;

# %%
# %sql
-- create schema for test
CREATE SCHEMA test.bronze;
CREATE SCHEMA test.silver;
CREATE SCHEMA test.gold;

# %%
# %sql
-- create schema for prod
CREATE SCHEMA prod.bronze;
CREATE SCHEMA prod.silver;
CREATE SCHEMA prod.gold;

# %% [markdown]
# Create Volume (for file storage)

# %%
# %sql
-- for dev
CREATE VOLUME dev.bronze.raw_files;
CREATE VOLUME dev.silver.processed_files;
CREATE VOLUME dev.gold.analytics_files;

# %%
# %sql
-- for test
CREATE VOLUME test.bronze.raw_files;
CREATE VOLUME test.silver.processed_files;
CREATE VOLUME test.gold.analytics_files;

# %%
# %sql
-- for prod
CREATE VOLUME prod.bronze.raw_files;
CREATE VOLUME prod.silver.processed_files;
CREATE VOLUME prod.gold.analytics_files;

# %%
jdbc_url = "jdbc:mysql://127.0.0.1:3306/ecommerce"

connection_properties = {
    "user": "root",
    "password": "Ankit@312$",
    "driver": "com.mysql.cj.jdbc.Driver"
}

orders_df = spark.read.jdbc(
    url=jdbc_url,
    table="orders",
    properties=connection_properties
)

orders_df.write.format("delta").mode("overwrite").saveAsTable("dev.bronze.orders")
